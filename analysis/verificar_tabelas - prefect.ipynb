# %%
import os
import psycopg2
from sqlalchemy import create_engine
from dotenv import load_dotenv
import pandas as pd

# %%
# Parâmetros de conexão com o PostgreSQL
db_host = 'localhost'
db_port = os.getenv('PREFECT_DB_PORT')
db_database = os.getenv('PREFECT_DB_DATABASE')
db_user = os.getenv('PREFECT_DB_USER')
db_password = os.getenv('PREFECT_DB_PASSWORD')

# %%
try:
    # Testar conexão antes de prosseguir
    test_conn = psycopg2.connect(
        host=db_host,
        port=db_port,
        database=db_database,
        user=db_user,
        password=db_password
    )
    print("Conexão com o PostgreSQL estabelecida com sucesso!")
    test_conn.close()
except Exception as e:
    print(f"Erro ao estabelecer conexão com o PostgreSQL: {e}")
# Out:
# Conexão com o PostgreSQL estabelecida com sucesso!

# %%
engine = create_engine(f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_database}')

# %%
query = """-- Listar Tabelas
SELECT table_schema, table_name, 'table' AS type
FROM information_schema.tables
WHERE --table_schema IN ('bronze', 'silver', 'gold')
  --AND 
  table_type = 'BASE TABLE'

UNION

-- Listar Views
SELECT table_schema, table_name, 'view' AS type
FROM information_schema.views
--WHERE table_schema IN ('bronze', 'silver', 'gold')

UNION

-- Listar Views Materializadas
SELECT schemaname, matviewname AS table_name, 'materialized view' AS type
FROM pg_matviews
--WHERE schemaname IN ('bronze', 'silver', 'gold')
ORDER BY table_schema, table_name;
"""
available_tables = pd.read_sql(query, con=engine)
available_tables
# Out:
#     table_schema             table_name   type
# 0    hdb_catalog  event_invocation_logs  table
# 1    hdb_catalog              event_log  table
# 2    hdb_catalog         event_triggers  table
# 3    hdb_catalog             hdb_action  table
# 4    hdb_catalog         hdb_action_log  table
# ..           ...                    ...    ...
# 235       public               task_run  table
# 236       public      task_run_artifact  table
# 237       public         task_run_state  table
# 238       public                 tenant  table
# 239      utility              traversal  table
#
# [240 rows x 3 columns]

# %%
pd.read_sql("SELECT * FROM public.flow_run", con=engine)
# Out:
#                                       id  \
# 0   dee4eaf2-0675-4cd7-a351-0c9241f3064d
# 1   e8fc2b10-a1ab-4135-b25d-6e3e58ef36a8
# 2   c33a5d49-df56-4e1d-9e1f-76cdd07da47e
# 3   f73ed390-92e8-40c8-8b6e-b43198c7aae8
# 4   55b6dd4c-b874-440f-8b28-fca09f10fa6d
# 5   8ee008e1-04ce-41f8-956e-ace9c9a6e660
# 6   2edaf360-51cb-478f-9bdf-d7716be62815
# 7   7b03f578-94ff-4c84-99d3-ce8acdc7ddce
# 8   ce905e51-7aa1-4dc7-96a5-5ba7d4366b70
# 9   e1080e68-9234-412f-bd2e-0b82d365e4d3
# 10  4041ba6d-d6ac-4e21-b90f-ca62f6caa88f
# 11  0b39e03c-8761-40a9-b54e-e118a7d31ef3
# 12  1a1d71d2-d791-471d-8451-e6ae78e971bb
# 13  f6f82328-3abd-446c-8f0b-de4300f58420
# 14  839fb283-2e52-4912-82c5-4028da2b8aaa
#
#                                tenant_id                          created  \
# 0   54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:02:02.482010+00:00
# 1   54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:07:03.518366+00:00
# 2   54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:02:02.465302+00:00
# 3   54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:02:02.475294+00:00
# 4   54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:07:03.519889+00:00
# 5   54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:07:03.527283+00:00
# 6   54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:02:02.475593+00:00
# 7   54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:04:27.126569+00:00
# 8   54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:02:02.482255+00:00
# 9   54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:04:27.133651+00:00
# 10  54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:02:02.482278+00:00
# 11  54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:02:02.488573+00:00
# 12  54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:02:02.489296+00:00
# 13  54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:02:02.478530+00:00
# 14  54163aa8-7d17-489e-adbf-f4b110ee06bd 2025-01-23 06:02:02.465277+00:00
#
#                                  flow_id  \
# 0   04910e29-18ec-4abe-8289-49ef23639d1b
# 1   04910e29-18ec-4abe-8289-49ef23639d1b
# 2   04910e29-18ec-4abe-8289-49ef23639d1b
# 3   04910e29-18ec-4abe-8289-49ef23639d1b
# 4   04910e29-18ec-4abe-8289-49ef23639d1b
# 5   04910e29-18ec-4abe-8289-49ef23639d1b
# 6   04910e29-18ec-4abe-8289-49ef23639d1b
# 7   04910e29-18ec-4abe-8289-49ef23639d1b
# 8   04910e29-18ec-4abe-8289-49ef23639d1b
# 9   04910e29-18ec-4abe-8289-49ef23639d1b
# 10  04910e29-18ec-4abe-8289-49ef23639d1b
# 11  04910e29-18ec-4abe-8289-49ef23639d1b
# 12  04910e29-18ec-4abe-8289-49ef23639d1b
# 13  04910e29-18ec-4abe-8289-49ef23639d1b
# 14  04910e29-18ec-4abe-8289-49ef23639d1b
#
#                                            parameters  \
# 0   {'materialization_mode': 'dev', 'materialize_a...
# 1   {'materialization_mode': 'dev', 'materialize_a...
# 2   {'materialization_mode': 'dev', 'materialize_a...
# 3   {'materialization_mode': 'dev', 'materialize_a...
# 4   {'materialization_mode': 'dev', 'materialize_a...
# 5   {'materialization_mode': 'dev', 'materialize_a...
# 6   {'materialization_mode': 'dev', 'materialize_a...
# 7   {'materialization_mode': 'dev', 'materialize_a...
# 8   {'materialization_mode': 'dev', 'materialize_a...
# 9   {'materialization_mode': 'dev', 'materialize_a...
# 10  {'materialization_mode': 'dev', 'materialize_a...
# 11  {'materialization_mode': 'dev', 'materialize_a...
# 12  {'materialization_mode': 'dev', 'materialize_a...
# 13  {'materialization_mode': 'dev', 'materialize_a...
# 14  {'materialization_mode': 'dev', 'materialize_a...
#
#         scheduled_start_time  auto_scheduled                        heartbeat  \
# 0  2025-01-23 06:11:00+00:00            True                              NaT
# 1  2025-01-23 06:17:00+00:00            True                              NaT
# 2  2025-01-23 06:03:00+00:00            True 2025-01-23 06:03:02.943164+00:00
# 3  2025-01-23 06:05:00+00:00            True 2025-01-23 06:05:01.383581+00:00
# 4  2025-01-23 06:15:00+00:00            True                              NaT
# 5  2025-01-23 06:16:00+00:00            True                              NaT
# 6  2025-01-23 06:06:00+00:00            True 2025-01-23 06:06:02.709747+00:00
# 7  2025-01-23 06:14:00+00:00            True                              NaT
# 8  2025-01-23 06:08:00+00:00            True 2025-01-23 06:08:01.410348+00:00
# 9  2025-01-23 06:13:00+00:00            True                              NaT
# 10 2025-01-23 06:09:00+00:00            True                              NaT
# 11 2025-01-23 06:07:00+00:00            True 2025-01-23 06:07:02.682082+00:00
# 12 2025-01-23 06:12:00+00:00            True                              NaT
# 13 2025-01-23 06:10:00+00:00            True                              NaT
# 14 2025-01-23 06:04:00+00:00            True 2025-01-23 06:04:02.187278+00:00
#
#                          start_time                         end_time  ...  \
# 0                               NaT                              NaT  ...
# 1                               NaT                              NaT  ...
# 2  2025-01-23 06:03:02.463632+00:00 2025-01-23 06:03:04.550764+00:00  ...
# 3  2025-01-23 06:05:00.931347+00:00 2025-01-23 06:05:03.377234+00:00  ...
# 4                               NaT                              NaT  ...
# 5                               NaT                              NaT  ...
# 6  2025-01-23 06:06:02.223240+00:00 2025-01-23 06:06:04.355404+00:00  ...
# 7                               NaT                              NaT  ...
# 8  2025-01-23 06:08:00.904282+00:00 2025-01-23 06:08:02.865406+00:00  ...
# 9                               NaT                              NaT  ...
# 10                              NaT                              NaT  ...
# 11 2025-01-23 06:07:02.156036+00:00 2025-01-23 06:07:04.156529+00:00  ...
# 12                              NaT                              NaT  ...
# 13                              NaT                              NaT  ...
# 14 2025-01-23 06:04:01.526833+00:00 2025-01-23 06:04:03.594580+00:00  ...
#
#             state_start_time  \
# 0  2025-01-23 06:11:00+00:00
# 1  2025-01-23 06:17:00+00:00
# 2                        NaT
# 3                        NaT
# 4  2025-01-23 06:15:00+00:00
# 5  2025-01-23 06:16:00+00:00
# 6                        NaT
# 7  2025-01-23 06:14:00+00:00
# 8                        NaT
# 9  2025-01-23 06:13:00+00:00
# 10 2025-01-23 06:09:00+00:00
# 11                       NaT
# 12 2025-01-23 06:12:00+00:00
# 13 2025-01-23 06:10:00+00:00
# 14                       NaT
#
#                                      serialized_state                  name  \
# 0   {'type': 'Scheduled', '_result': {'type': 'NoR...       spotted-octopus
# 1   {'type': 'Scheduled', '_result': {'type': 'NoR...     careful-centipede
# 2   {'type': 'Success', '_result': {'type': 'Resul...           crazy-stork
# 3   {'type': 'Success', '_result': {'type': 'Resul...       nano-woodpecker
# 4   {'type': 'Scheduled', '_result': {'type': 'NoR...          esoteric-ant
# 5   {'type': 'Scheduled', '_result': {'type': 'NoR...        premium-petrel
# 6   {'type': 'Success', '_result': {'type': 'Resul...            ruddy-gaur
# 7   {'type': 'Scheduled', '_result': {'type': 'NoR...          khaki-oyster
# 8   {'type': 'Success', '_result': {'type': 'Resul...      pastoral-jacamar
# 9   {'type': 'Scheduled', '_result': {'type': 'NoR...        micro-nuthatch
# 10  {'type': 'Scheduled', '_result': {'type': 'NoR...     unbiased-goldfish
# 11  {'type': 'Success', '_result': {'type': 'Resul...         meteoric-clam
# 12  {'type': 'Scheduled', '_result': {'type': 'NoR...        notorious-rook
# 13  {'type': 'Scheduled', '_result': {'type': 'NoR...  courageous-butterfly
# 14  {'type': 'Success', '_result': {'type': 'Resul...   phenomenal-smilodon
#
#    context times_resurrected                          updated  \
# 0       {}                 0 2025-01-23 06:07:03.560134+00:00
# 1       {}                 0 2025-01-23 06:07:03.560134+00:00
# 2       {}                 0 2025-01-23 06:03:04.554490+00:00
# 3       {}                 0 2025-01-23 06:05:03.382699+00:00
# 4       {}                 0 2025-01-23 06:07:03.560134+00:00
# 5       {}                 0 2025-01-23 06:07:03.560134+00:00
# 6       {}                 0 2025-01-23 06:06:04.359773+00:00
# 7       {}                 0 2025-01-23 06:07:03.560134+00:00
# 8       {}                 0 2025-01-23 06:08:02.868854+00:00
# 9       {}                 0 2025-01-23 06:07:03.560134+00:00
# 10      {}                 0 2025-01-23 06:07:03.560134+00:00
# 11      {}                 0 2025-01-23 06:07:04.160626+00:00
# 12      {}                 0 2025-01-23 06:07:03.560134+00:00
# 13      {}                 0 2025-01-23 06:07:03.560134+00:00
# 14      {}                 0 2025-01-23 06:04:03.597636+00:00
#
#                                       idempotency_key  \
# 0   auto-scheduled:2025-01-23T06:11:00+00:00:3ce13...
# 1   auto-scheduled:2025-01-23T06:17:00+00:00:3ce13...
# 2   auto-scheduled:2025-01-23T06:03:00+00:00:3ce13...
# 3   auto-scheduled:2025-01-23T06:05:00+00:00:3ce13...
# 4   auto-scheduled:2025-01-23T06:15:00+00:00:3ce13...
# 5   auto-scheduled:2025-01-23T06:16:00+00:00:3ce13...
# 6   auto-scheduled:2025-01-23T06:06:00+00:00:3ce13...
# 7   auto-scheduled:2025-01-23T06:14:00+00:00:3ce13...
# 8   auto-scheduled:2025-01-23T06:08:00+00:00:3ce13...
# 9   auto-scheduled:2025-01-23T06:13:00+00:00:3ce13...
# 10  auto-scheduled:2025-01-23T06:09:00+00:00:3ce13...
# 11  auto-scheduled:2025-01-23T06:07:00+00:00:3ce13...
# 12  auto-scheduled:2025-01-23T06:12:00+00:00:3ce13...
# 13  auto-scheduled:2025-01-23T06:10:00+00:00:3ce13...
# 14  auto-scheduled:2025-01-23T06:04:00+00:00:3ce13...
#
#                                 agent_id       labels  \
# 0                                   None  [pipelines]
# 1                                   None  [pipelines]
# 2   a7f215fe-5968-4551-81bc-12c1a0bd7c5a  [pipelines]
# 3   a7f215fe-5968-4551-81bc-12c1a0bd7c5a  [pipelines]
# 4                                   None  [pipelines]
# 5                                   None  [pipelines]
# 6   a7f215fe-5968-4551-81bc-12c1a0bd7c5a  [pipelines]
# 7                                   None  [pipelines]
# 8   a7f215fe-5968-4551-81bc-12c1a0bd7c5a  [pipelines]
# 9                                   None  [pipelines]
# 10                                  None  [pipelines]
# 11  a7f215fe-5968-4551-81bc-12c1a0bd7c5a  [pipelines]
# 12                                  None  [pipelines]
# 13                                  None  [pipelines]
# 14  a7f215fe-5968-4551-81bc-12c1a0bd7c5a  [pipelines]
#
#                                            run_config
# 0   {'env': None, 'type': 'LocalRun', 'labels': ['...
# 1   {'env': None, 'type': 'LocalRun', 'labels': ['...
# 2   {'env': None, 'type': 'LocalRun', 'labels': ['...
# 3   {'env': None, 'type': 'LocalRun', 'labels': ['...
# 4   {'env': None, 'type': 'LocalRun', 'labels': ['...
# 5   {'env': None, 'type': 'LocalRun', 'labels': ['...
# 6   {'env': None, 'type': 'LocalRun', 'labels': ['...
# 7   {'env': None, 'type': 'LocalRun', 'labels': ['...
# 8   {'env': None, 'type': 'LocalRun', 'labels': ['...
# 9   {'env': None, 'type': 'LocalRun', 'labels': ['...
# 10  {'env': None, 'type': 'LocalRun', 'labels': ['...
# 11  {'env': None, 'type': 'LocalRun', 'labels': ['...
# 12  {'env': None, 'type': 'LocalRun', 'labels': ['...
# 13  {'env': None, 'type': 'LocalRun', 'labels': ['...
# 14  {'env': None, 'type': 'LocalRun', 'labels': ['...
#
# [15 rows x 25 columns]
